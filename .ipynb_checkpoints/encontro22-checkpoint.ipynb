# %% [markdown]
# # Encontro 22: Mundos Pequenos
#
# Importando as bibliotecas:

# %%
import sys
sys.path.append('..')

import socnet as sn
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Atividade 1
#
# Definindo uma função que gera um grafo aleatório tal que a probabilidade de uma aresta existir é `c` sobre o número de nós:

# %%
from random import random

def generate_random_graph(num_nodes, c):
    g = sn.generate_empty_graph(num_nodes)
 
    nodes = list(g.nodes)
 
    for i in range(num_nodes):
        n = nodes[i]
 
        for j in range(i + 1, num_nodes):
            m = nodes[j]
 
            if random() < c / num_nodes:
                g.add_edge(n, m)
 
    return g

# %% [markdown]
# Gerando um grafo passando parâmetros específicos para a função acima.

# %%
N = 100
C = 10

rg = generate_random_graph(N, C)

# %% [markdown]
# Verificando se a distribuição dos graus de `pg` segue uma Poisson com média `C`:

# %%
from scipy.stats import poisson


x = range(N)

plt.hist([rg.degree(n) for n in rg.nodes], x, normed=True)

plt.plot(x, poisson.pmf(C, x));

# %% [markdown]
# Calculando variação de *clustering coefficient* e *average distance* conforme aumentamos `num_nodes`:

# %%
x = []

rcc = []
rad = []

for num_nodes in range(C + 1, N):
    g = generate_random_graph(num_nodes, C)

    x.append(num_nodes)

    rcc.append(sn.clustering_coefficient(g))
    rad.append(sn.average_distance(g))

# %% [markdown]
# Plotando variação de *clustering coefficient*:

# %%
plt.plot(x, rcc);

# %% [markdown]
# Plotando variação de *average distance*:

# %%
plt.plot(x, rad);

# %% [markdown]
# ## Atividade 2
#
# Definindo uma função que gera um grafo circular:

# %%
def generate_circular_graph(num_nodes, c):
    g = sn.generate_empty_graph(num_nodes)
    
    # Antes de completar essa função, estime qual
    # vai ser a aparência dos dois gráficos abaixo.
    n = g.number_of_nodes()
    nodes = g.nodes()
    for i in range(n):
        for j in range(c // 2):
            g.add_edge(i, (j + i) % n)

    return g

# %% [markdown]
# Calculando variação de *clustering coefficient* e *average distance* conforme aumentamos `num_nodes`:

# %%
ccc = []
cad = []

for num_nodes in x:
    g = generate_circular_graph(num_nodes, C)

    ccc.append(sn.clustering_coefficient(g))
    cad.append(sn.average_distance(g))

# %% [markdown]
# Plotando variação de *clustering coefficient*:

# %%
plt.plot(x, ccc);

# %% [markdown]
# Plotando variação de *average distance*:

# %%
plt.plot(x, cad);

# %% [markdown]
# ## Atividade 3
#
# Definindo uma função que gera um grafo híbrido:

# %%
from random import choice, randint


def redo_edge(g, n, i):
    if g.number_of_nodes() <= 1:
        return
    
    g.remove_edge(n, i)
    
    while True:
        m = randint(0, g.number_of_nodes() - 1)  # nao escalavel
        if m != n:
            break
        
    g.add_edge(n, m)
    


def generate_hybrid_graph(num_nodes, c, p):
    g = generate_circular_graph(num_nodes, c)

    # Antes de completar essa função, estime qual
    # vai ser a aparência dos dois gráficos abaixo.
    for n in g.nodes():
        for i in range(c):
            if random() < p:
                redo_edge(g, n, (i + n) % c)

    return g

# %% [markdown]
# Os próximos gráficos serão para `N` e `C` fixos. Por conveniência, vamos repetir a definição.

# %%
N = 100
C = 10

# %% [markdown]
# Calculando variação de *clustering coefficient* e *average distance* conforme aumentamos `p`:

# %%
x = []

hcc = []
had = []

for ip in range(0, 11):
    p = ip / 10

    g = generate_hybrid_graph(N, C, p)

    x.append(p)

    hcc.append(sn.clustering_coefficient(g))
    had.append(sn.average_distance(g))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/gil/.local/lib/python3.5/site-packages/networkx/classes/graph.py in remove_edge(self, u, v)
#    1004         try:
# -> 1005             del self._adj[u][v]
#    1006             if u != v:  # self-loop needs only one entry removed
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-61-babdd78fa408> in <module>()
#       7     p = ip / 10
#       8
# ----> 9     g = generate_hybrid_graph(N, C, p)
#      10
#      11     x.append(p)
#
# <ipython-input-59-f5f24bca62e5> in generate_hybrid_graph(num_nodes, c, p)
#      25         for i in range(c):
#      26             if random() > p:
# ---> 27                 redo_edge(g, n, (i + n) % c)
#      28
#      29     return g
#
# <ipython-input-59-f5f24bca62e5> in redo_edge(g, n, i)
#       6         return
#       7
# ----> 8     g.remove_edge(n, i)
#       9
#      10     while True:
#
# /home/gil/.local/lib/python3.5/site-packages/networkx/classes/graph.py in remove_edge(self, u, v)
#    1007                 del self._adj[v][u]
#    1008         except KeyError:
# -> 1009             raise NetworkXError("The edge %s-%s is not in the graph" % (u, v))
#    1010
#    1011     def remove_edges_from(self, ebunch):
#
# NetworkXError: The edge 0-5 is not in the graph

# %% [markdown]
# Comparando variação de *clustering coefficient* com o valor de referência do modelo aleatório.
#
# Em um "pequeno mundo", espera-se um *clustering coefficient* acima desse valor de referência.

# %%
plt.plot(x, 11 * [C / N])
plt.plot(x, hcc);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-f4a33bc039b0> in <module>()
# ----> 1 plt.plot(x, 11 * [C / N])
#       2 plt.plot(x, hcc);
#
# /home/gil/.local/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /home/gil/.local/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /home/gil/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /home/gil/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /home/gil/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# /home/gil/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (0,) and (11,)

# %% [markdown]
# Comparando variação de *average distance* com o valor de referência do modelo circular.
#
# Em um "pequeno mundo", espera-se um *average distance* abaixo desse valor de referência.

# %%
plt.plot(x, 11 * [N / (2 * C)])
plt.plot(x, had);

# %% [markdown]
# Para qual valor de `p` temos um "pequeno mundo"?
